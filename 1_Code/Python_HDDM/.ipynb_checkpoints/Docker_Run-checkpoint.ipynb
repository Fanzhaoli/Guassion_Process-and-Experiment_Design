# %%
# ⚠️ 此单元格在 Docker 容器内运行
# 复制到 Docker Jupyter Notebook 中执行

import pandas as pd
import numpy as np
from pathlib import Path
import sys
import warnings
warnings.filterwarnings("ignore")

# 🔥 修复：使用你真实有权限的挂载目录
BASE_DIR = Path("/home/jovyan/work")
DATA_DIR = BASE_DIR / "2_Data" / "Real_Data" / "HDDM_Ready"
OUT_DIR  = BASE_DIR / "2_Data" / "Real_Data" / "HDDM_Traces"
OUT_DIR.mkdir(parents=True, exist_ok=True)

csv_files = sorted(DATA_DIR.glob("hddm_data_group*.csv"))
print(f"发现 {len(csv_files)} 个待拟合文件")

for csv_path in csv_files:
    fname = csv_path.stem
    print(f"\n{'=' * 50}")
    print(f"拟合: {fname}")
    print(f"{'=' * 50}")

    df = pd.read_csv(csv_path)
    n_subj = df["subj_idx"].nunique()
    print(f"  被试: {n_subj}, 试次: {len(df)}")
    print(f"  Self: {(df['identity']==1).sum()}, Stranger: {(df['identity']==0).sum()}")
    print(f"  遗漏: {df['omission'].sum()}")

    df_fit = df.copy().dropna(subset=["rt"])
    if len(df_fit) < 50:
        print(f"  ⚠️ 有效试次过少 ({len(df_fit)}), 跳过")
        continue

    import hddm

    model = hddm.HDDM(
        df_fit,
        depends_on={"v": "identity"},
        include=["v", "a", "t", "z"],
        bias=False,
        p_outlier=0.05,
    )

    print("  开始 MCMC 采样...")
    model.sample(3000, burn=500, dbname="traces.db", db="pickle")
    print("  采样完成")

    traces = model.get_traces()
    npz_path = OUT_DIR / f"{fname}_traces.npz"
    trace_dict = {}
    for key, val in traces.items():
        if isinstance(val, np.ndarray):
            trace_dict[key] = val
        elif isinstance(val, pd.DataFrame):
            trace_dict[key] = val.values
    np.savez_compressed(npz_path, **trace_dict)

    stats = model.gen_stats()
    stats.to_csv(OUT_DIR / f"{fname}_stats.csv")

    print(f"  迹线 → {npz_path}")
    print(f"  统计 → {OUT_DIR / f'{fname}_stats.csv'}")

print(f"\n{'=' * 50}")
print("✅ 所有拟合完成!")
# Out:
# 发现 8 个待拟合文件
#
# ==================================================
# 拟合: hddm_data_group1_P0_T30_W300
# ==================================================
#   被试: 11, 试次: 2860
#   Self: 1430, Stranger: 1430
#   遗漏: 2068
# No model attribute --> setting up standard HDDM
# Set model to ddm
#   开始 MCMC 采样...
#  [-----------------100%-----------------] 3000 of 3000 complete in 266.4 sechddm sampling elpased time:  266.519 s
#   采样完成
#   迹线 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group1_P0_T30_W300_traces.npz
#   统计 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group1_P0_T30_W300_stats.csv
#
# ==================================================
# 拟合: hddm_data_group2_P0_T30_W600
# ==================================================
#   被试: 12, 试次: 3120
#   Self: 1560, Stranger: 1560
#   遗漏: 1636
# No model attribute --> setting up standard HDDM
# Set model to ddm
#   开始 MCMC 采样...
#  [-----------------100%-----------------] 3000 of 3000 complete in 244.0 sechddm sampling elpased time:  244.12 s
#   采样完成
#   迹线 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group2_P0_T30_W600_traces.npz
#   统计 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group2_P0_T30_W600_stats.csv
#
# ==================================================
# 拟合: hddm_data_group3_P120_T30_W600
# ==================================================
#   被试: 10, 试次: 2600
#   Self: 1300, Stranger: 1300
#   遗漏: 1004
# No model attribute --> setting up standard HDDM
# Set model to ddm
#   开始 MCMC 采样...
#  [-----------------100%-----------------] 3001 of 3000 complete in 121.6 sechddm sampling elpased time:  121.626 s
#   采样完成
#   迹线 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group3_P120_T30_W600_traces.npz
#   统计 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group3_P120_T30_W600_stats.csv
#
# ==================================================
# 拟合: hddm_data_group4_P120_T80_W600
# ==================================================
#   被试: 11, 试次: 2860
#   Self: 1430, Stranger: 1430
#   遗漏: 1098
# No model attribute --> setting up standard HDDM
# Set model to ddm
#   开始 MCMC 采样...
#  [-----------------100%-----------------] 3001 of 3000 complete in 116.4 sechddm sampling elpased time:  116.471 s
#   采样完成
#   迹线 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group4_P120_T80_W600_traces.npz
#   统计 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group4_P120_T80_W600_stats.csv
#
# ==================================================
# 拟合: hddm_data_group5_P8_T100_W1100
# ==================================================
#   被试: 11, 试次: 2860
#   Self: 1430, Stranger: 1430
#   遗漏: 313
# No model attribute --> setting up standard HDDM
# Set model to ddm
#   开始 MCMC 采样...
#  [-----------------100%-----------------] 3001 of 3000 complete in 111.2 sechddm sampling elpased time:  111.257 s
#   采样完成
#   迹线 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group5_P8_T100_W1100_traces.npz
#   统计 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group5_P8_T100_W1100_stats.csv
#
# ==================================================
# 拟合: hddm_data_group6_P120_T500_W1500
# ==================================================
#   被试: 10, 试次: 2600
#   Self: 1300, Stranger: 1300
#   遗漏: 146
# No model attribute --> setting up standard HDDM
# Set model to ddm
#   开始 MCMC 采样...
#  [-----------------100%-----------------] 3000 of 3000 complete in 97.6 sechddm sampling elpased time:  97.697 s
#   采样完成
#   迹线 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group6_P120_T500_W1500_traces.npz
#   统计 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group6_P120_T500_W1500_stats.csv
#
# ==================================================
# 拟合: hddm_data_group7_P120_T80_W800
# ==================================================
#   被试: 12, 试次: 3120
#   Self: 1560, Stranger: 1560
#   遗漏: 446
# No model attribute --> setting up standard HDDM
# Set model to ddm
#   开始 MCMC 采样...
#  [-----------------100%-----------------] 3000 of 3000 complete in 120.8 sechddm sampling elpased time:  120.917 s
#   采样完成
#   迹线 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group7_P120_T80_W800_traces.npz
#   统计 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group7_P120_T80_W800_stats.csv
#
# ==================================================
# 拟合: hddm_data_group8_P120_T80_W800
# ==================================================
#   被试: 11, 试次: 2860
#   Self: 1430, Stranger: 1430
#   遗漏: 420
# No model attribute --> setting up standard HDDM
# Set model to ddm
#   开始 MCMC 采样...
#  [-----------------100%-----------------] 3000 of 3000 complete in 111.1 sechddm sampling elpased time:  111.223 s
#   采样完成
#   迹线 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group8_P120_T80_W800_traces.npz
#   统计 → /home/jovyan/work/2_Data/Real_Data/HDDM_Traces/hddm_data_group8_P120_T80_W800_stats.csv
#
# ==================================================
# ✅ 所有拟合完成!
